# %%
pip install magent2
# Out:
# Collecting magent2
#   Downloading magent2-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy<2.0,>=1.21.0 in /opt/conda/lib/python3.10/site-packages (from magent2) (1.26.4)
# Collecting pygame>=2.1.0 (from magent2)
#   Downloading pygame-2.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Requirement already satisfied: pettingzoo>=1.23.1 in /opt/conda/lib/python3.10/site-packages (from magent2) (1.24.0)
# Requirement already satisfied: gymnasium>=0.28.0 in /opt/conda/lib/python3.10/site-packages (from pettingzoo>=1.23.1->magent2) (0.29.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.28.0->pettingzoo>=1.23.1->magent2) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.28.0->pettingzoo>=1.23.1->magent2) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.28.0->pettingzoo>=1.23.1->magent2) (0.0.4)
# Downloading magent2-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 20.6 MB/s eta 0:00:0000:010:01
# Downloading pygame-2.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 81.1 MB/s eta 0:00:00:00:0100:01
# Installing collected packages: pygame, magent2
# Successfully installed magent2-0.3.3 pygame-2.6.1
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pettingzoo==1.22.0
# Out:
# Collecting pettingzoo==1.22.0
#   Downloading PettingZoo-1.22.0-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: numpy>=1.18.0 in /opt/conda/lib/python3.10/site-packages (from pettingzoo==1.22.0) (1.26.4)
# Requirement already satisfied: gymnasium>=0.26.0 in /opt/conda/lib/python3.10/site-packages (from pettingzoo==1.22.0) (0.29.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.26.0->pettingzoo==1.22.0) (3.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.26.0->pettingzoo==1.22.0) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /opt/conda/lib/python3.10/site-packages (from gymnasium>=0.26.0->pettingzoo==1.22.0) (0.0.4)
# Downloading PettingZoo-1.22.0-py3-none-any.whl (823 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.4/823.4 kB 12.1 MB/s eta 0:00:00 0:00:01
# Installing collected packages: pettingzoo
#   Attempting uninstall: pettingzoo
#     Found existing installation: pettingzoo 1.24.0
#     Uninstalling pettingzoo-1.24.0:
#       Successfully uninstalled pettingzoo-1.24.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kaggle-environments 1.16.9 requires pettingzoo==1.24.0, but you have pettingzoo 1.22.0 which is incompatible.
# magent2 0.3.3 requires pettingzoo>=1.23.1, but you have pettingzoo 1.22.0 which is incompatible.
# Successfully installed pettingzoo-1.22.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
torch.autograd.set_detect_anomaly(True)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from magent2.environments import battle_v4
import numpy as np
from torch.utils.tensorboard import SummaryWriter
import os
import datetime
from collections import deque
import random

# --- Noisy Linear Layer ---

class NoisyLinear(nn.Module):
    """
    implements noisy linear layer with factorized Gaussian noise parameters.
    used for exploration in Deep Q-networks instead of epsilon-greedy.
    input: Regular linear layer parameters
    output: Linear transformation with added parameterized noise
    """
    def __init__(self, in_features, out_features, std_init=0.5):
        super(NoisyLinear, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.std_init = std_init

        self.weight_mu = nn.Parameter(torch.empty(out_features, in_features))
        self.weight_sigma = nn.Parameter(torch.empty(out_features, in_features))
        self.register_buffer('weight_epsilon', torch.empty(out_features, in_features))

        self.bias_mu = nn.Parameter(torch.empty(out_features))
        self.bias_sigma = nn.Parameter(torch.empty(out_features))
        self.register_buffer('bias_epsilon', torch.empty(out_features))

        self.reset_parameters()
        self.reset_noise()

    def reset_parameters(self):
        mu_range = 1 / np.sqrt(self.in_features)
        self.weight_mu.data.uniform_(-mu_range, mu_range)
        self.weight_sigma.data.fill_(self.std_init / np.sqrt(self.in_features))
        self.bias_mu.data.uniform_(-mu_range, mu_range)
        self.bias_sigma.data.fill_(self.std_init / np.sqrt(self.out_features))

    def _scale_noise(self, size):
        x = torch.randn(size)
        return x.sign().mul_(x.abs().sqrt_())

    def reset_noise(self):
        epsilon_in = self._scale_noise(self.in_features)
        epsilon_out = self._scale_noise(self.out_features)
        self.weight_epsilon = epsilon_out.ger(epsilon_in).to(self.weight_mu.device) # Create new tensors instead of in-place copy
        self.bias_epsilon = epsilon_out.to(self.bias_mu.device) # Create new tensors instead of in-place copy

    def forward(self, input):
        if self.training:
            return nn.functional.linear(input, self.weight_mu + self.weight_sigma * self.weight_epsilon, self.bias_mu + self.bias_sigma * self.bias_epsilon)
        else:
            return nn.functional.linear(input, self.weight_mu, self.bias_mu)

# %%
# --- Dueling Q-Network with Noisy Layers ---

class DuelingQNetwork(nn.Module):
    """
    neural network implementing Dueling architecture with Noisy layers.
    separates state value and advantage functions.
    uses noisy linear layers for exploration.
    input: game state observation
    output: Q-values for each action
    """
    def __init__(self, observation_shape, action_shape):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(observation_shape[-1], observation_shape[-1], 3),
            nn.ReLU(),
            nn.Conv2d(observation_shape[-1], observation_shape[-1], 3),
            nn.ReLU(),
        )
        dummy_input = torch.randn(observation_shape).permute(2, 0, 1).unsqueeze(0)
        dummy_output = self.cnn(dummy_input)
        flatten_dim = dummy_output.view(-1).shape[0]

        self.fc_value = nn.Sequential(
            NoisyLinear(flatten_dim, 128),
            nn.ReLU(),
            NoisyLinear(128, 1)
        )

        self.fc_advantage = nn.Sequential(
            NoisyLinear(flatten_dim, 128),
            nn.ReLU(),
            NoisyLinear(128, action_shape)
        )

    def forward(self, x):
        x = x.permute(0, 3, 1, 2)
        x = self.cnn(x)
        x = x.reshape(x.size(0), -1)
        value = self.fc_value(x)
        advantage = self.fc_advantage(x)
        return value + advantage - advantage.mean(dim=1, keepdim=True)

    def reset_noise(self):
        for module in self.children():
          for layer in module:
            if isinstance(layer, NoisyLinear):
                layer.reset_noise()

# %%
# --- Hypernetwork-based VDN Mixer ---

class HyperVDNMixer(nn.Module):
    """
    value decomposition network using hypernetworks to mix agent Q-values.
    combines individual agent values into team value using dynamic weights.
    input: Individual agent Q-values and states  
    output: Team Q-value
    """
    def __init__(self, n_agents, hypernet_embed=64):
        super().__init__()
        self.n_agents = n_agents
        self.embed_dim = hypernet_embed

        # Hypernetwork layers
        self.hyper_w_1 = nn.Sequential(
            nn.Linear(self.n_agents, self.embed_dim),
            nn.ReLU(),
            nn.Linear(self.embed_dim, self.n_agents)  # Outputting weights for the first layer
        )
        self.hyper_w_final = nn.Linear(self.n_agents, 1)  # Outputting weights for the final layer

    def forward(self, agent_qs, states):
        # State embedding (using agent's positions as a simple state representation)
        agent_positions = states.mean(dim=(2,3))[:,:self.n_agents]
        # First layer
        w1 = torch.abs(self.hyper_w_1(agent_positions))
        b1 = torch.mean(agent_qs,dim=1,keepdim=True)
        hidden = nn.functional.elu(torch.bmm(agent_qs.view(-1, 1, self.n_agents), w1.view(-1, self.n_agents, 1)) + b1)

        # Second layer
        w_final = torch.abs(self.hyper_w_final(agent_positions))
        y = torch.bmm(hidden, w_final.view(-1, 1, 1))

        # Reshape and return
        q_total = y.view(-1, 1, 1)
        return q_total

# %%
class RedQNetwork(nn.Module):
    def __init__(self, observation_shape, action_shape):
        super().__init__()
        self.cnn = nn.Sequential(
            nn.Conv2d(observation_shape[-1], observation_shape[-1], 3),
            nn.ReLU(),
            nn.Conv2d(observation_shape[-1], observation_shape[-1], 3),
            nn.ReLU(),
        )
        dummy_input = torch.randn(observation_shape).permute(2, 0, 1)
        dummy_output = self.cnn(dummy_input)
        flatten_dim = dummy_output.view(-1).shape[0]
        self.network = nn.Sequential(
            nn.Linear(flatten_dim, 120),
            nn.ReLU(),
            nn.Linear(120, 84),
            nn.ReLU(),
            nn.Linear(84, action_shape),
        )

    def forward(self, x):
        assert len(x.shape) >= 3, "only support magent input observation"
        x = self.cnn(x)
        if len(x.shape) == 3:
            batchsize = 1
        else:
            batchsize = x.shape[0]
        x = x.reshape(batchsize, -1)
        return self.network(x)

# %%
# --- Prioritized Replay Buffer ---

class PrioritizedReplayBuffer:
    def __init__(self, capacity, alpha=0.6, beta_start=0.4, beta_frames=100000):
        self.capacity = capacity
        self.buffer = []
        self.priorities = np.zeros((capacity,), dtype=np.float32)
        self.alpha = alpha
        self.beta_start = beta_start
        self.beta_frames = beta_frames
        self.frame = 1
        self.pos = 0
        self.max_priority = 1.0

    def push(self, state, action, reward, next_state, done):
        if len(self.buffer) < self.capacity:
            self.buffer.append((state, action, reward, next_state, done))
        else:
            self.buffer[self.pos] = (state, action, reward, next_state, done)

        self.priorities[self.pos] = self.max_priority
        self.pos = (self.pos + 1) % self.capacity

    def sample(self, batch_size):
        if len(self.buffer) == self.capacity:
            prios = self.priorities
        else:
            prios = self.priorities[:self.pos]

        probs = prios ** self.alpha
        probs /= probs.sum()

        indices = np.random.choice(len(self.buffer), batch_size, p=probs)
        samples = [self.buffer[idx] for idx in indices]

        beta = self.beta_start + (1.0 - self.beta_start) * self.frame / self.beta_frames
        self.frame = min(self.frame + 1, self.beta_frames)

        weights = (len(self.buffer) * probs[indices]) ** (-beta)
        weights /= weights.max()
        weights = np.array(weights, dtype=np.float32)

        state, action, reward, next_state, done = zip(*samples)
        return state, action, reward, next_state, done, indices, weights

    def update_priorities(self, batch_indices, batch_priorities):
        for idx, prio in zip(batch_indices, batch_priorities):
            self.priorities[idx] = prio.item()  # Convert to a standard Python number
        self.max_priority = max(self.max_priority, max(batch_priorities, default=self.max_priority).item())

    def __len__(self):
        return len(self.buffer)

# %%
def evaluate_checkpoint(q_network, red_q_network, pretrain_policy, num_episodes=5):
    env = battle_v4.parallel_env(map_size=45, max_cycles=1000, minimap_mode=False)
    total_steps = 0
    total_rewards_random = 0
    total_rewards_pretrained = 0

    for _ in range(num_episodes):
        # --- Evaluate against random policy ---
        observations = env.reset()
        done_agents = set()
        episode_reward_random = 0
        while True:
            actions = {}
            red_agents = [agent for agent in env.agents if agent.startswith("red_") and agent not in done_agents]
            blue_agents = [agent for agent in env.agents if agent.startswith("blue_") and agent not in done_agents]

            if red_agents:
                for agent in red_agents:
                    actions[agent] = env.action_spaces[agent].sample()  # Random action

            if blue_agents:
                states_blue = torch.stack([
                    torch.tensor(observations[agent], dtype=torch.float32)
                    for agent in blue_agents
                ]).to(device)
                with torch.no_grad():
                    q_network_blue.reset_noise()          
                    q_values_blue = q_network(states_blue)
                    selected_actions_blue = torch.argmax(q_values_blue, dim=1)

                for idx, agent in enumerate(blue_agents):
                    actions[agent] = selected_actions_blue[idx].item()

            next_obs, rewards, terminations, truncations, infos = env.step(actions)
            done_agents.update([agent for agent, terminated in terminations.items() if terminated])
            observations = next_obs
            episode_reward_random += sum(rewards.get(agent, 0.0) for agent in blue_agents)
            if all(terminations.values()) or all(truncations.values()):
                total_rewards_random += episode_reward_random
                break

        # --- Evaluate against pretrained policy ---
        observations = env.reset()
        done_agents = set()
        episode_reward_pretrained = 0
        while True:
            actions = {}
            red_agents = [agent for agent in env.agents if agent.startswith("red_") and agent not in done_agents]
            blue_agents = [agent for agent in env.agents if agent.startswith("blue_") and agent not in done_agents]

            if red_agents:
                for agent in red_agents:
                    actions[agent] = pretrain_policy(env, agent, observations[agent])  # Pretrained action

            if blue_agents:
                states_blue = torch.stack([
                    torch.tensor(observations[agent], dtype=torch.float32)
                    for agent in blue_agents
                ]).to(device)
                with torch.no_grad():
                    q_network_blue.reset_noise() 
                    q_values_blue = q_network(states_blue)
                    selected_actions_blue = torch.argmax(q_values_blue, dim=1)

                for idx, agent in enumerate(blue_agents):
                    actions[agent] = selected_actions_blue[idx].item()

            next_obs, rewards, terminations, truncations, infos = env.step(actions)
            done_agents.update([agent for agent, terminated in terminations.items() if terminated])
            observations = next_obs
            episode_reward_pretrained += sum(rewards.get(agent, 0.0) for agent in blue_agents)
            if all(terminations.values()) or all(truncations.values()):
                total_rewards_pretrained += episode_reward_pretrained
                break

    avg_reward_random = total_rewards_random / num_episodes
    avg_reward_pretrained = total_rewards_pretrained / num_episodes
    avg_reward = (avg_reward_random + avg_reward_pretrained) / 2

    return avg_reward, avg_reward_random, avg_reward_pretrained

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")

# --- TensorBoard writer ---

log_dir = os.path.join("runs", "Noisy_Dueling_VDN_PER_HyperMixer_BattleV4_" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))
writer = SummaryWriter(log_dir=log_dir)

# --- Initialize the environment ---

env = battle_v4.parallel_env(map_size=45, max_cycles=1000, minimap_mode=False)

sample_observation = env.observation_spaces[env.agents[0]].shape
state_space = sample_observation
action_space = env.action_spaces[env.agents[0]].n
n_agents = len([agent for agent in env.agents if agent.startswith("blue_")])

# --- Initialize networks and optimizers ---

q_network_blue = DuelingQNetwork(state_space, action_space).to(device)
target_network_blue = DuelingQNetwork(state_space, action_space).to(device)
target_network_blue.load_state_dict(q_network_blue.state_dict())
target_network_blue.eval()

vdn_mixer_blue = HyperVDNMixer(n_agents).to(device)

optimizer_blue = optim.Adam(list(q_network_blue.parameters()) + list(vdn_mixer_blue.parameters()), lr=0.0005)

# --- Hyperparameters ---
gamma = 0.99
num_episodes = 500
max_steps_per_episode = 1000
checkpoint_interval = 5
polyak_tau = 0.005
replay_buffer_size = 500000
batch_size = 4096
num_val_episodes = 5
# --- Initialize replay buffers ---

replay_buffer_blue = PrioritizedReplayBuffer(replay_buffer_size)
red_q_network = RedQNetwork(state_space, action_space).to(device)  # Assuming same architecture
red_q_network.load_state_dict(torch.load("/kaggle/input/redpt/other/default/1/red.pt", map_location=device))
red_q_network.eval()

def pretrain_policy(env, agent, obs):
    observation = (torch.Tensor(obs).float().permute([2, 0, 1]).unsqueeze(0).to(device))
    with torch.no_grad():
        red_q_values = red_q_network(observation)
    return torch.argmax(red_q_values, dim=1).cpu().numpy()[0]
    
# --- Training loop ---

best_val = -float('inf')
best_checkpoint = ""
torch.autograd.set_detect_anomaly(False) # Turn off after debugging
for episode in range(0, num_episodes + 1):
    observations = env.reset()
    
    # --- Reset noise in the networks at the beginning of each episode
    q_network_blue.reset_noise()
    target_network_blue.reset_noise()
    
    total_reward_blue = 0
    done_agents = set()

    for step in range(max_steps_per_episode):
        actions = {}
        red_agents = [agent for agent in env.agents if agent.startswith("red_") and agent not in done_agents]
        blue_agents = [agent for agent in env.agents if agent.startswith("blue_") and agent not in done_agents]

        # --- Random actions for red agents ---
        if red_agents:
            for agent in red_agents:
                actions[agent] = np.random.randint(0, action_space)

        # --- Process all blue agents ---
        if blue_agents:
            states_blue = torch.stack([
                torch.tensor(observations[agent], dtype=torch.float32)
                for agent in blue_agents
            ]).to(device)

            # --- Select actions ---
            with torch.no_grad():
                q_values_blue = q_network_blue(states_blue)
                selected_actions_blue = torch.argmax(q_values_blue, dim=1)

            for idx, agent in enumerate(blue_agents):
                actions[agent] = selected_actions_blue[idx].item()

        # --- Take step in environment ---
        next_obs, rewards, terminations, truncations, infos = env.step(actions)

        # --- Update total rewards ---
        total_reward_blue += sum(rewards.get(agent, 0.0) for agent in blue_agents)

        for agent in blue_agents:
            # Handle cases where next_obs might not be available for done agents
            next_state = next_obs.get(agent) if not terminations.get(agent, False) else observations[agent]

            replay_buffer_blue.push(
                observations[agent],
                actions[agent],
                rewards.get(agent, 0.0),
                next_state,
                terminations.get(agent, False)
            )

        # --- Update done_agents based on terminations ---
        done_agents.update([agent for agent, terminated in terminations.items() if terminated])

        # --- Train blue network on a batch sampled from replay buffer ---
        if len(replay_buffer_blue) >= batch_size:
            state_batch, action_batch, reward_batch, next_state_batch, done_batch, indices, weights = replay_buffer_blue.sample(batch_size)
            
            current_states_blue = torch.tensor(np.array(state_batch), dtype=torch.float32).to(device)
            current_actions_blue = torch.tensor(action_batch, dtype=torch.long).to(device)
            next_states_blue = torch.tensor(np.array(next_state_batch), dtype=torch.float32).to(device)
            rewards_blue = torch.tensor(reward_batch, dtype=torch.float32).to(device)
            dones_blue = torch.tensor(done_batch, dtype=torch.float32).to(device)
            weights_tensor_blue = torch.tensor(weights, dtype=torch.float32).unsqueeze(1).to(device)
            
            # Reset noise outside of torch.no_grad()
            q_network_blue.reset_noise()
            target_network_blue.reset_noise()

            current_q_values_blue = q_network_blue(current_states_blue).gather(1, current_actions_blue.unsqueeze(1))

            with torch.no_grad():
              next_actions_blue = q_network_blue(next_states_blue).max(1, keepdim=True)[1]
              target_q_values_blue = target_network_blue(next_states_blue).gather(1, next_actions_blue)

            
            rewards_blue = rewards_blue.unsqueeze(1)
            dones_blue = dones_blue.unsqueeze(1)
            
            target_q_values_blue = rewards_blue + gamma * target_q_values_blue * (1 - dones_blue)

            td_errors = (target_q_values_blue - current_q_values_blue).abs().detach().cpu().numpy()
            new_priorities = td_errors + 1e-6
            replay_buffer_blue.update_priorities(indices, new_priorities)

            loss_blue = (weights_tensor_blue * nn.SmoothL1Loss(reduction='none')(current_q_values_blue, target_q_values_blue)).mean()

            optimizer_blue.zero_grad()
            loss_blue.backward()
            nn.utils.clip_grad_norm_(list(q_network_blue.parameters())+ list(vdn_mixer_blue.parameters()), 1.0)
            optimizer_blue.step()

            writer.add_scalar('Loss/Blue', loss_blue.item(), episode * max_steps_per_episode + step)

        # --- Soft update target networks ---
        for target_param, param in zip(target_network_blue.parameters(), q_network_blue.parameters()):
            target_param.data.copy_(polyak_tau * param.data + (1 - polyak_tau) * target_param.data)

        observations = next_obs

        # Check for episode termination (either all terminated or max_cycles reached)
        if all(terminations.values()) or (truncations and all(truncations.values())):
            break

    # --- Log episode statistics ---

    writer.add_scalar('Total Reward/Blue', total_reward_blue, episode)
    print(f"Episode {episode}/{num_episodes}, Total Reward Blue: {total_reward_blue:.2f}")

    # --- Save checkpoints and evaluate ---

    if episode % checkpoint_interval == 0:
      checkpoint_path = f"blue_agent_noisy_dueling_vdn_per_hypermixer_ep{episode}.pth"
      torch.save({
          'q_network_blue_state_dict': q_network_blue.state_dict(),
          'vdn_mixer_blue_state_dict': vdn_mixer_blue.state_dict(),
      }, checkpoint_path)
      val_reward, val_reward_random, val_reward_pretrained = evaluate_checkpoint(q_network_blue, red_q_network, pretrain_policy, num_val_episodes)
      writer.add_scalar('Validation/Average Reward', val_reward, episode)
      writer.add_scalar('Validation/Average Reward vs Random', val_reward_random, episode)
      writer.add_scalar('Validation/Average Reward vs Pretrained', val_reward_pretrained, episode)
      print(f"Episode {episode}: Validation average reward = {val_reward:.2f}, "
              f"vs Random = {val_reward_random:.2f}, vs Pretrained = {val_reward_pretrained:.2f}")
      if val_reward >= best_val:
            best_val = val_reward
            if best_checkpoint:
                os.remove(best_checkpoint)
            best_checkpoint = checkpoint_path
            print(f"New best checkpoint saved at {best_checkpoint}")
      if val_reward < best_val:
            os.remove(checkpoint_path)
if best_checkpoint:
    best_checkpoint_final = "blue_agent_noisy_dueling_vdn_hypermixer_best.pth"
    os.rename(best_checkpoint, best_checkpoint_final)
    print(f"Training complete. Best model saved at {best_checkpoint_final}")
else:
    torch.save({
        'q_network_blue_state_dict': q_network_blue.state_dict(),
        'vdn_mixer_blue_state_dict': vdn_mixer_blue.state_dict(),
    }, "blue_agent_noisy_dueling_vdn_hypermixer_final.pth")
    print(f"Training complete. Final model saved at blue_agent_noisy_dueling_vdn_per_hypermixer_final.pth")
# Out:
# Using device: cuda
# /tmp/ipykernel_23/2465235017.py:42: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   red_q_network.load_state_dict(torch.load("/kaggle/input/redpt/other/default/1/red.pt", map_location=device))
# Episode 0/500, Total Reward Blue: -1473.56
# Episode 0: Validation average reward = -1195.79, vs Random = -2241.79, vs Pretrained = -149.79
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep0.pth
# Episode 1/500, Total Reward Blue: -861.90
# Episode 2/500, Total Reward Blue: -427.90
# Episode 3/500, Total Reward Blue: 43.19
# Episode 4/500, Total Reward Blue: -77.02
# Episode 5/500, Total Reward Blue: 364.45
# Episode 5: Validation average reward = 3.06, vs Random = -18.90, vs Pretrained = 25.03
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep5.pth
# Episode 6/500, Total Reward Blue: -36.42
# Episode 7/500, Total Reward Blue: -567.98
# Episode 8/500, Total Reward Blue: 316.08
# Episode 9/500, Total Reward Blue: 350.91
# Episode 10/500, Total Reward Blue: 319.34
# Episode 10: Validation average reward = 200.05, vs Random = 356.47, vs Pretrained = 43.62
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep10.pth
# Episode 11/500, Total Reward Blue: 360.92
# Episode 12/500, Total Reward Blue: 362.77
# Episode 13/500, Total Reward Blue: 372.40
# Episode 14/500, Total Reward Blue: 342.82
# Episode 15/500, Total Reward Blue: 367.05
# Episode 15: Validation average reward = 195.18, vs Random = 364.14, vs Pretrained = 26.22
# Episode 16/500, Total Reward Blue: 368.41
# Episode 17/500, Total Reward Blue: 367.44
# Episode 18/500, Total Reward Blue: 371.54
# Episode 19/500, Total Reward Blue: 374.60
# Episode 20/500, Total Reward Blue: 382.19
# Episode 20: Validation average reward = 210.52, vs Random = 368.22, vs Pretrained = 52.82
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep20.pth
# Episode 21/500, Total Reward Blue: 371.35
# Episode 22/500, Total Reward Blue: 369.77
# Episode 23/500, Total Reward Blue: 371.36
# Episode 24/500, Total Reward Blue: 384.36
# Episode 25/500, Total Reward Blue: 374.98
# Episode 25: Validation average reward = 156.54, vs Random = 308.15, vs Pretrained = 4.94
# Episode 26/500, Total Reward Blue: 379.31
# Episode 27/500, Total Reward Blue: 375.67
# Episode 28/500, Total Reward Blue: 373.86
# Episode 29/500, Total Reward Blue: 365.52
# Episode 30/500, Total Reward Blue: 365.48
# Episode 30: Validation average reward = 198.54, vs Random = 360.35, vs Pretrained = 36.74
# Episode 31/500, Total Reward Blue: 379.17
# Episode 32/500, Total Reward Blue: 369.32
# Episode 33/500, Total Reward Blue: 361.48
# Episode 34/500, Total Reward Blue: 372.80
# Episode 35/500, Total Reward Blue: 372.54
# Episode 35: Validation average reward = 193.25, vs Random = 355.48, vs Pretrained = 31.02
# Episode 36/500, Total Reward Blue: 368.44
# Episode 37/500, Total Reward Blue: 365.85
# Episode 38/500, Total Reward Blue: 369.29
# Episode 39/500, Total Reward Blue: 369.35
# Episode 40/500, Total Reward Blue: 369.65
# Episode 40: Validation average reward = 203.32, vs Random = 376.11, vs Pretrained = 30.53
# Episode 41/500, Total Reward Blue: 376.62
# Episode 42/500, Total Reward Blue: 360.23
# Episode 43/500, Total Reward Blue: 373.89
# Episode 44/500, Total Reward Blue: 370.76
# Episode 45/500, Total Reward Blue: 379.97
# Episode 45: Validation average reward = 222.14, vs Random = 377.20, vs Pretrained = 67.09
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep45.pth
# Episode 46/500, Total Reward Blue: 385.12
# Episode 47/500, Total Reward Blue: 378.51
# Episode 48/500, Total Reward Blue: 363.89
# Episode 49/500, Total Reward Blue: 378.94
# Episode 50/500, Total Reward Blue: 378.99
# Episode 50: Validation average reward = 237.07, vs Random = 379.96, vs Pretrained = 94.17
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep50.pth
# Episode 51/500, Total Reward Blue: 385.92
# Episode 52/500, Total Reward Blue: 363.94
# Episode 53/500, Total Reward Blue: 377.13
# Episode 54/500, Total Reward Blue: 382.25
# Episode 55/500, Total Reward Blue: 365.12
# Episode 55: Validation average reward = 247.76, vs Random = 379.06, vs Pretrained = 116.46
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep55.pth
# Episode 56/500, Total Reward Blue: 366.22
# Episode 57/500, Total Reward Blue: 370.90
# Episode 58/500, Total Reward Blue: 374.46
# Episode 59/500, Total Reward Blue: 381.73
# Episode 60/500, Total Reward Blue: 375.94
# Episode 60: Validation average reward = 244.96, vs Random = 371.83, vs Pretrained = 118.09
# Episode 61/500, Total Reward Blue: 374.99
# Episode 62/500, Total Reward Blue: 378.10
# Episode 63/500, Total Reward Blue: 362.04
# Episode 64/500, Total Reward Blue: 376.96
# Episode 65/500, Total Reward Blue: 382.64
# Episode 65: Validation average reward = 294.53, vs Random = 368.90, vs Pretrained = 220.16
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep65.pth
# Episode 66/500, Total Reward Blue: 382.87
# Episode 67/500, Total Reward Blue: 376.68
# Episode 68/500, Total Reward Blue: 384.44
# Episode 69/500, Total Reward Blue: 377.65
# Episode 70/500, Total Reward Blue: 380.49
# Episode 70: Validation average reward = 269.06, vs Random = 379.21, vs Pretrained = 158.91
# Episode 71/500, Total Reward Blue: 385.87
# Episode 72/500, Total Reward Blue: 388.75
# Episode 73/500, Total Reward Blue: 370.28
# Episode 74/500, Total Reward Blue: 378.63
# Episode 75/500, Total Reward Blue: 385.61
# Episode 75: Validation average reward = 334.76, vs Random = 382.15, vs Pretrained = 287.37
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep75.pth
# Episode 76/500, Total Reward Blue: 388.64
# Episode 77/500, Total Reward Blue: 389.48
# Episode 78/500, Total Reward Blue: 392.91
# Episode 79/500, Total Reward Blue: 380.10
# Episode 80/500, Total Reward Blue: 375.08
# Episode 80: Validation average reward = 331.94, vs Random = 377.76, vs Pretrained = 286.12
# Episode 81/500, Total Reward Blue: 385.75
# Episode 82/500, Total Reward Blue: 385.65
# Episode 83/500, Total Reward Blue: 388.73
# Episode 84/500, Total Reward Blue: 386.50
# Episode 85/500, Total Reward Blue: 386.40
# Episode 85: Validation average reward = 360.57, vs Random = 383.41, vs Pretrained = 337.74
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep85.pth
# Episode 86/500, Total Reward Blue: 383.62
# Episode 87/500, Total Reward Blue: 383.56
# Episode 88/500, Total Reward Blue: 384.96
# Episode 89/500, Total Reward Blue: 385.69
# Episode 90/500, Total Reward Blue: 385.89
# Episode 90: Validation average reward = 346.09, vs Random = 384.95, vs Pretrained = 307.24
# Episode 91/500, Total Reward Blue: 379.21
# Episode 92/500, Total Reward Blue: 386.63
# Episode 93/500, Total Reward Blue: 390.22
# Episode 94/500, Total Reward Blue: 390.22
# Episode 95/500, Total Reward Blue: 383.86
# Episode 95: Validation average reward = 368.78, vs Random = 383.65, vs Pretrained = 353.90
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep95.pth
# Episode 96/500, Total Reward Blue: 394.51
# Episode 97/500, Total Reward Blue: 392.24
# Episode 98/500, Total Reward Blue: 384.34
# Episode 99/500, Total Reward Blue: 377.51
# Episode 100/500, Total Reward Blue: 388.68
# Episode 100: Validation average reward = 312.09, vs Random = 387.22, vs Pretrained = 236.95
# Episode 101/500, Total Reward Blue: 392.91
# Episode 102/500, Total Reward Blue: 392.04
# Episode 103/500, Total Reward Blue: 391.64
# Episode 104/500, Total Reward Blue: 390.77
# Episode 105/500, Total Reward Blue: 391.27
# Episode 105: Validation average reward = 332.75, vs Random = 394.53, vs Pretrained = 270.97
# Episode 106/500, Total Reward Blue: 396.15
# Episode 107/500, Total Reward Blue: 382.96
# Episode 108/500, Total Reward Blue: 393.86
# Episode 109/500, Total Reward Blue: 398.29
# Episode 110/500, Total Reward Blue: 397.54
# Episode 110: Validation average reward = 304.23, vs Random = 392.24, vs Pretrained = 216.21
# Episode 111/500, Total Reward Blue: 394.42
# Episode 112/500, Total Reward Blue: 370.44
# Episode 113/500, Total Reward Blue: 371.32
# Episode 114/500, Total Reward Blue: 378.08
# Episode 115/500, Total Reward Blue: 318.65
# Episode 115: Validation average reward = 285.54, vs Random = 369.31, vs Pretrained = 201.76
# Episode 116/500, Total Reward Blue: 365.49
# Episode 117/500, Total Reward Blue: 346.62
# Episode 118/500, Total Reward Blue: 205.88
# Episode 119/500, Total Reward Blue: 266.44
# Episode 120/500, Total Reward Blue: 366.52
# Episode 120: Validation average reward = 268.24, vs Random = 338.25, vs Pretrained = 198.23
# Episode 121/500, Total Reward Blue: 142.39
# Episode 122/500, Total Reward Blue: 339.58
# Episode 123/500, Total Reward Blue: 361.25
# Episode 124/500, Total Reward Blue: 394.53
# Episode 125/500, Total Reward Blue: 362.19
# Episode 125: Validation average reward = 305.97, vs Random = 390.70, vs Pretrained = 221.24
# Episode 126/500, Total Reward Blue: 384.15
# Episode 127/500, Total Reward Blue: 388.64
# Episode 128/500, Total Reward Blue: 393.06
# Episode 129/500, Total Reward Blue: 381.91
# Episode 130/500, Total Reward Blue: 382.55
# Episode 130: Validation average reward = 317.47, vs Random = 385.77, vs Pretrained = 249.18
# Episode 131/500, Total Reward Blue: 374.12
# Episode 132/500, Total Reward Blue: 390.48
# Episode 133/500, Total Reward Blue: 393.02
# Episode 134/500, Total Reward Blue: 396.64
# Episode 135/500, Total Reward Blue: 388.14
# Episode 135: Validation average reward = 369.28, vs Random = 378.63, vs Pretrained = 359.92
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep135.pth
# Episode 136/500, Total Reward Blue: 393.07
# Episode 137/500, Total Reward Blue: 390.33
# Episode 138/500, Total Reward Blue: 396.43
# Episode 139/500, Total Reward Blue: 356.77
# Episode 140/500, Total Reward Blue: 397.32
# Episode 140: Validation average reward = 317.74, vs Random = 385.76, vs Pretrained = 249.72
# Episode 141/500, Total Reward Blue: 398.23
# Episode 142/500, Total Reward Blue: 393.02
# Episode 143/500, Total Reward Blue: 394.60
# Episode 144/500, Total Reward Blue: 393.87
# Episode 145/500, Total Reward Blue: 388.83
# Episode 145: Validation average reward = 351.16, vs Random = 385.93, vs Pretrained = 316.38
# Episode 146/500, Total Reward Blue: 353.33
# Episode 147/500, Total Reward Blue: 395.72
# Episode 148/500, Total Reward Blue: 386.71
# Episode 149/500, Total Reward Blue: 400.85
# Episode 150/500, Total Reward Blue: 398.56
# Episode 150: Validation average reward = 315.20, vs Random = 390.15, vs Pretrained = 240.24
# Episode 151/500, Total Reward Blue: 392.30
# Episode 152/500, Total Reward Blue: 381.84
# Episode 153/500, Total Reward Blue: 389.93
# Episode 154/500, Total Reward Blue: 389.58
# Episode 155/500, Total Reward Blue: 400.25
# Episode 155: Validation average reward = 359.85, vs Random = 386.08, vs Pretrained = 333.62
# Episode 156/500, Total Reward Blue: 402.08
# Episode 157/500, Total Reward Blue: 397.17
# Episode 158/500, Total Reward Blue: 398.85
# Episode 159/500, Total Reward Blue: 319.99
# Episode 160/500, Total Reward Blue: 391.55
# Episode 160: Validation average reward = 363.95, vs Random = 391.85, vs Pretrained = 336.05
# Episode 161/500, Total Reward Blue: 393.60
# Episode 162/500, Total Reward Blue: 400.45
# Episode 163/500, Total Reward Blue: 392.66
# Episode 164/500, Total Reward Blue: 398.83
# Episode 165/500, Total Reward Blue: 391.43
# Episode 165: Validation average reward = 377.28, vs Random = 395.25, vs Pretrained = 359.30
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep165.pth
# Episode 166/500, Total Reward Blue: 383.01
# Episode 167/500, Total Reward Blue: 392.29
# Episode 168/500, Total Reward Blue: 396.36
# Episode 169/500, Total Reward Blue: 395.90
# Episode 170/500, Total Reward Blue: 401.35
# Episode 170: Validation average reward = 381.83, vs Random = 397.81, vs Pretrained = 365.85
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep170.pth
# Episode 171/500, Total Reward Blue: 399.73
# Episode 172/500, Total Reward Blue: 396.27
# Episode 173/500, Total Reward Blue: 404.27
# Episode 174/500, Total Reward Blue: 394.66
# Episode 175/500, Total Reward Blue: 403.71
# Episode 175: Validation average reward = 392.49, vs Random = 396.87, vs Pretrained = 388.10
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep175.pth
# Episode 176/500, Total Reward Blue: 403.56
# Episode 177/500, Total Reward Blue: 400.26
# Episode 178/500, Total Reward Blue: 401.64
# Episode 179/500, Total Reward Blue: 395.58
# Episode 180/500, Total Reward Blue: 402.91
# Episode 180: Validation average reward = 379.56, vs Random = 398.22, vs Pretrained = 360.89
# Episode 181/500, Total Reward Blue: 399.06
# Episode 182/500, Total Reward Blue: 398.44
# Episode 183/500, Total Reward Blue: 391.89
# Episode 184/500, Total Reward Blue: 372.61
# Episode 185/500, Total Reward Blue: 397.88
# Episode 185: Validation average reward = 390.58, vs Random = 396.74, vs Pretrained = 384.43
# Episode 186/500, Total Reward Blue: 390.26
# Episode 187/500, Total Reward Blue: 388.23
# Episode 188/500, Total Reward Blue: 393.91
# Episode 189/500, Total Reward Blue: 401.25
# Episode 190/500, Total Reward Blue: 402.35
# Episode 190: Validation average reward = 381.09, vs Random = 396.88, vs Pretrained = 365.29
# Episode 191/500, Total Reward Blue: 393.88
# Episode 192/500, Total Reward Blue: 401.15
# Episode 193/500, Total Reward Blue: 404.89
# Episode 194/500, Total Reward Blue: 400.47
# Episode 195/500, Total Reward Blue: 377.63
# Episode 195: Validation average reward = 394.78, vs Random = 396.52, vs Pretrained = 393.04
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep195.pth
# Episode 196/500, Total Reward Blue: 397.02
# Episode 197/500, Total Reward Blue: 390.87
# Episode 198/500, Total Reward Blue: 395.58
# Episode 199/500, Total Reward Blue: 395.67
# Episode 200/500, Total Reward Blue: 387.60
# Episode 200: Validation average reward = 385.67, vs Random = 398.51, vs Pretrained = 372.83
# Episode 201/500, Total Reward Blue: 402.56
# Episode 202/500, Total Reward Blue: 386.97
# Episode 203/500, Total Reward Blue: 403.46
# Episode 204/500, Total Reward Blue: 397.85
# Episode 205/500, Total Reward Blue: 400.92
# Episode 205: Validation average reward = 388.95, vs Random = 392.50, vs Pretrained = 385.39
# Episode 206/500, Total Reward Blue: 399.44
# Episode 207/500, Total Reward Blue: 400.13
# Episode 208/500, Total Reward Blue: 400.85
# Episode 209/500, Total Reward Blue: 398.28
# Episode 210/500, Total Reward Blue: 399.60
# Episode 210: Validation average reward = 356.93, vs Random = 386.99, vs Pretrained = 326.86
# Episode 211/500, Total Reward Blue: 398.41
# Episode 212/500, Total Reward Blue: 392.37
# Episode 213/500, Total Reward Blue: 402.71
# Episode 214/500, Total Reward Blue: 394.47
# Episode 215/500, Total Reward Blue: 400.72
# Episode 215: Validation average reward = 372.08, vs Random = 386.64, vs Pretrained = 357.52
# Episode 216/500, Total Reward Blue: 399.29
# Episode 217/500, Total Reward Blue: 396.57
# Episode 218/500, Total Reward Blue: 403.06
# Episode 219/500, Total Reward Blue: 402.04
# Episode 220/500, Total Reward Blue: 398.28
# Episode 220: Validation average reward = 393.10, vs Random = 395.26, vs Pretrained = 390.94
# Episode 221/500, Total Reward Blue: 400.97
# Episode 222/500, Total Reward Blue: 399.52
# Episode 223/500, Total Reward Blue: 402.85
# Episode 224/500, Total Reward Blue: 402.74
# Episode 225/500, Total Reward Blue: 396.99
# Episode 225: Validation average reward = 391.82, vs Random = 395.78, vs Pretrained = 387.85
# Episode 226/500, Total Reward Blue: 388.98
# Episode 227/500, Total Reward Blue: 400.02
# Episode 228/500, Total Reward Blue: 402.23
# Episode 229/500, Total Reward Blue: 399.93
# Episode 230/500, Total Reward Blue: 396.44
# Episode 230: Validation average reward = 399.62, vs Random = 397.81, vs Pretrained = 401.43
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep230.pth
# Episode 231/500, Total Reward Blue: 403.38
# Episode 232/500, Total Reward Blue: 394.43
# Episode 233/500, Total Reward Blue: 398.19
# Episode 234/500, Total Reward Blue: 404.61
# Episode 235/500, Total Reward Blue: 382.84
# Episode 235: Validation average reward = 399.83, vs Random = 400.66, vs Pretrained = 399.00
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep235.pth
# Episode 236/500, Total Reward Blue: 401.46
# Episode 237/500, Total Reward Blue: 396.79
# Episode 238/500, Total Reward Blue: 395.17
# Episode 239/500, Total Reward Blue: 396.38
# Episode 240/500, Total Reward Blue: 398.90
# Episode 240: Validation average reward = 398.25, vs Random = 401.12, vs Pretrained = 395.38
# Episode 241/500, Total Reward Blue: 401.32
# Episode 242/500, Total Reward Blue: 399.53
# Episode 243/500, Total Reward Blue: 401.85
# Episode 244/500, Total Reward Blue: 394.36
# Episode 245/500, Total Reward Blue: 400.32
# Episode 245: Validation average reward = 355.67, vs Random = 350.25, vs Pretrained = 361.09
# Episode 246/500, Total Reward Blue: 399.05
# Episode 247/500, Total Reward Blue: 392.35
# Episode 248/500, Total Reward Blue: 374.21
# Episode 249/500, Total Reward Blue: 400.72
# Episode 250/500, Total Reward Blue: 320.54
# Episode 250: Validation average reward = 396.78, vs Random = 398.37, vs Pretrained = 395.18
# Episode 251/500, Total Reward Blue: 402.56
# Episode 252/500, Total Reward Blue: 397.60
# Episode 253/500, Total Reward Blue: 395.19
# Episode 254/500, Total Reward Blue: 378.07
# Episode 255/500, Total Reward Blue: 402.55
# Episode 255: Validation average reward = 399.23, vs Random = 400.86, vs Pretrained = 397.60
# Episode 256/500, Total Reward Blue: 404.27
# Episode 257/500, Total Reward Blue: 403.96
# Episode 258/500, Total Reward Blue: 399.76
# Episode 259/500, Total Reward Blue: 384.37
# Episode 260/500, Total Reward Blue: 404.96
# Episode 260: Validation average reward = 381.79, vs Random = 393.50, vs Pretrained = 370.08
# Episode 261/500, Total Reward Blue: 389.72
# Episode 262/500, Total Reward Blue: 368.36
# Episode 263/500, Total Reward Blue: 393.26
# Episode 264/500, Total Reward Blue: 405.97
# Episode 265/500, Total Reward Blue: 402.64
# Episode 265: Validation average reward = 397.42, vs Random = 398.95, vs Pretrained = 395.89
# Episode 266/500, Total Reward Blue: 380.59
# Episode 267/500, Total Reward Blue: 396.20
# Episode 268/500, Total Reward Blue: 375.47
# Episode 269/500, Total Reward Blue: 398.07
# Episode 270/500, Total Reward Blue: 393.58
# Episode 270: Validation average reward = 337.93, vs Random = 290.87, vs Pretrained = 385.00
# Episode 271/500, Total Reward Blue: 391.22
# Episode 272/500, Total Reward Blue: 403.96
# Episode 273/500, Total Reward Blue: -54.60
# Episode 274/500, Total Reward Blue: 407.16
# Episode 275/500, Total Reward Blue: 401.56
# Episode 275: Validation average reward = 372.02, vs Random = 399.52, vs Pretrained = 344.53
# Episode 276/500, Total Reward Blue: 404.86
# Episode 277/500, Total Reward Blue: 392.65
# Episode 278/500, Total Reward Blue: 389.47
# Episode 279/500, Total Reward Blue: 400.92
# Episode 280/500, Total Reward Blue: 403.76
# Episode 280: Validation average reward = 336.44, vs Random = 399.95, vs Pretrained = 272.93
# Episode 281/500, Total Reward Blue: 397.05
# Episode 282/500, Total Reward Blue: 401.45
# Episode 283/500, Total Reward Blue: 381.75
# Episode 284/500, Total Reward Blue: 401.85
# Episode 285/500, Total Reward Blue: 405.29
# Episode 285: Validation average reward = 379.97, vs Random = 400.86, vs Pretrained = 359.09
# Episode 286/500, Total Reward Blue: 389.92
# Episode 287/500, Total Reward Blue: 390.12
# Episode 288/500, Total Reward Blue: 407.78
# Episode 289/500, Total Reward Blue: 400.41
# Episode 290/500, Total Reward Blue: 402.53
# Episode 290: Validation average reward = 392.36, vs Random = 397.30, vs Pretrained = 387.41
# Episode 291/500, Total Reward Blue: 395.47
# Episode 292/500, Total Reward Blue: 399.69
# Episode 293/500, Total Reward Blue: 406.37
# Episode 294/500, Total Reward Blue: 401.54
# Episode 295/500, Total Reward Blue: 404.58
# Episode 295: Validation average reward = 349.61, vs Random = 308.73, vs Pretrained = 390.50
# Episode 296/500, Total Reward Blue: 397.38
# Episode 297/500, Total Reward Blue: 400.01
# Episode 298/500, Total Reward Blue: 405.56
# Episode 299/500, Total Reward Blue: 395.98
# Episode 300/500, Total Reward Blue: 331.59
# Episode 300: Validation average reward = 392.93, vs Random = 393.82, vs Pretrained = 392.05
# Episode 301/500, Total Reward Blue: 396.59
# Episode 302/500, Total Reward Blue: 408.39
# Episode 303/500, Total Reward Blue: 378.06
# Episode 304/500, Total Reward Blue: 394.03
# Episode 305/500, Total Reward Blue: 380.76
# Episode 305: Validation average reward = 399.32, vs Random = 400.07, vs Pretrained = 398.57
# Episode 306/500, Total Reward Blue: 397.93
# Episode 307/500, Total Reward Blue: 403.86
# Episode 308/500, Total Reward Blue: 393.03
# Episode 309/500, Total Reward Blue: 401.31
# Episode 310/500, Total Reward Blue: 391.68
# Episode 310: Validation average reward = 364.34, vs Random = 367.07, vs Pretrained = 361.62
# Episode 311/500, Total Reward Blue: 400.72
# Episode 312/500, Total Reward Blue: 391.20
# Episode 313/500, Total Reward Blue: 400.15
# Episode 314/500, Total Reward Blue: 403.75
# Episode 315/500, Total Reward Blue: 401.23
# Episode 315: Validation average reward = 390.28, vs Random = 403.94, vs Pretrained = 376.62
# Episode 316/500, Total Reward Blue: 388.59
# Episode 317/500, Total Reward Blue: 406.72
# Episode 318/500, Total Reward Blue: 395.05
# Episode 319/500, Total Reward Blue: 406.27
# Episode 320/500, Total Reward Blue: 405.47
# Episode 320: Validation average reward = 400.82, vs Random = 397.77, vs Pretrained = 403.87
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep320.pth
# Episode 321/500, Total Reward Blue: 407.38
# Episode 322/500, Total Reward Blue: 390.33
# Episode 323/500, Total Reward Blue: 404.56
# Episode 324/500, Total Reward Blue: 405.24
# Episode 325/500, Total Reward Blue: 369.97
# Episode 325: Validation average reward = 395.28, vs Random = 387.52, vs Pretrained = 403.04
# Episode 326/500, Total Reward Blue: 403.78
# Episode 327/500, Total Reward Blue: 404.68
# Episode 328/500, Total Reward Blue: 404.65
# Episode 329/500, Total Reward Blue: 378.71
# Episode 330/500, Total Reward Blue: 404.46
# Episode 330: Validation average reward = 398.16, vs Random = 398.76, vs Pretrained = 397.56
# Episode 331/500, Total Reward Blue: 404.85
# Episode 332/500, Total Reward Blue: 405.18
# Episode 333/500, Total Reward Blue: 408.00
# Episode 334/500, Total Reward Blue: 400.06
# Episode 335/500, Total Reward Blue: 405.68
# Episode 335: Validation average reward = 387.52, vs Random = 378.83, vs Pretrained = 396.20
# Episode 336/500, Total Reward Blue: 389.10
# Episode 337/500, Total Reward Blue: 402.54
# Episode 338/500, Total Reward Blue: 409.90
# Episode 339/500, Total Reward Blue: 400.33
# Episode 340/500, Total Reward Blue: 403.47
# Episode 340: Validation average reward = 400.49, vs Random = 397.63, vs Pretrained = 403.35
# Episode 341/500, Total Reward Blue: 401.65
# Episode 342/500, Total Reward Blue: 406.69
# Episode 343/500, Total Reward Blue: 404.54
# Episode 344/500, Total Reward Blue: 410.41
# Episode 345/500, Total Reward Blue: 406.18
# Episode 345: Validation average reward = 373.39, vs Random = 348.48, vs Pretrained = 398.30
# Episode 346/500, Total Reward Blue: 391.94
# Episode 347/500, Total Reward Blue: 401.94
# Episode 348/500, Total Reward Blue: 407.39
# Episode 349/500, Total Reward Blue: 407.57
# Episode 350/500, Total Reward Blue: 404.57
# Episode 350: Validation average reward = 393.62, vs Random = 392.23, vs Pretrained = 395.01
# Episode 351/500, Total Reward Blue: 396.50
# Episode 352/500, Total Reward Blue: 399.53
# Episode 353/500, Total Reward Blue: 403.53
# Episode 354/500, Total Reward Blue: 407.98
# Episode 355/500, Total Reward Blue: 405.16
# Episode 355: Validation average reward = 403.86, vs Random = 407.02, vs Pretrained = 400.69
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep355.pth
# Episode 356/500, Total Reward Blue: 402.54
# Episode 357/500, Total Reward Blue: 409.18
# Episode 358/500, Total Reward Blue: 402.84
# Episode 359/500, Total Reward Blue: 405.26
# Episode 360/500, Total Reward Blue: 404.20
# Episode 360: Validation average reward = 402.29, vs Random = 405.60, vs Pretrained = 398.98
# Episode 361/500, Total Reward Blue: 409.88
# Episode 362/500, Total Reward Blue: 409.99
# Episode 363/500, Total Reward Blue: 410.28
# Episode 364/500, Total Reward Blue: 407.88
# Episode 365/500, Total Reward Blue: 409.37
# Episode 365: Validation average reward = 380.83, vs Random = 400.68, vs Pretrained = 360.98
# Episode 366/500, Total Reward Blue: 407.10
# Episode 367/500, Total Reward Blue: 401.29
# Episode 368/500, Total Reward Blue: 399.53
# Episode 369/500, Total Reward Blue: 409.10
# Episode 370/500, Total Reward Blue: 407.28
# Episode 370: Validation average reward = 402.42, vs Random = 400.93, vs Pretrained = 403.90
# Episode 371/500, Total Reward Blue: 408.48
# Episode 372/500, Total Reward Blue: 406.56
# Episode 373/500, Total Reward Blue: 406.47
# Episode 374/500, Total Reward Blue: 407.40
# Episode 375/500, Total Reward Blue: 396.28
# Episode 375: Validation average reward = 368.22, vs Random = 331.80, vs Pretrained = 404.63
# Episode 376/500, Total Reward Blue: 398.61
# Episode 377/500, Total Reward Blue: 408.59
# Episode 378/500, Total Reward Blue: 401.41
# Episode 379/500, Total Reward Blue: 406.58
# Episode 380/500, Total Reward Blue: 400.74
# Episode 380: Validation average reward = 404.88, vs Random = 404.48, vs Pretrained = 405.29
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep380.pth
# Episode 381/500, Total Reward Blue: 407.68
# Episode 382/500, Total Reward Blue: 406.68
# Episode 383/500, Total Reward Blue: 380.16
# Episode 384/500, Total Reward Blue: 401.42
# Episode 385/500, Total Reward Blue: 400.93
# Episode 385: Validation average reward = 372.72, vs Random = 399.66, vs Pretrained = 345.78
# Episode 386/500, Total Reward Blue: 406.79
# Episode 387/500, Total Reward Blue: 405.68
# Episode 388/500, Total Reward Blue: 405.28
# Episode 389/500, Total Reward Blue: 268.39
# Episode 390/500, Total Reward Blue: 409.81
# Episode 390: Validation average reward = 368.65, vs Random = 403.79, vs Pretrained = 333.51
# Episode 391/500, Total Reward Blue: 402.86
# Episode 392/500, Total Reward Blue: 408.19
# Episode 393/500, Total Reward Blue: 409.09
# Episode 394/500, Total Reward Blue: 406.88
# Episode 395/500, Total Reward Blue: 405.38
# Episode 395: Validation average reward = 346.64, vs Random = 290.71, vs Pretrained = 402.57
# Episode 396/500, Total Reward Blue: 409.49
# Episode 397/500, Total Reward Blue: 385.74
# Episode 398/500, Total Reward Blue: 405.96
# Episode 399/500, Total Reward Blue: 407.69
# Episode 400/500, Total Reward Blue: 409.20
# Episode 400: Validation average reward = 406.59, vs Random = 404.69, vs Pretrained = 408.50
# New best checkpoint saved at blue_agent_noisy_dueling_vdn_per_hypermixer_ep400.pth
# Episode 401/500, Total Reward Blue: 409.49
# Episode 402/500, Total Reward Blue: 405.06
# Episode 403/500, Total Reward Blue: 410.48
# Episode 404/500, Total Reward Blue: 409.31
# Episode 405/500, Total Reward Blue: 408.45
# Episode 405: Validation average reward = 403.44, vs Random = 404.86, vs Pretrained = 402.02
# Episode 406/500, Total Reward Blue: 409.50
# Episode 407/500, Total Reward Blue: 408.79
# Episode 408/500, Total Reward Blue: 400.85
# Episode 409/500, Total Reward Blue: 401.66
# Episode 410/500, Total Reward Blue: 406.56
# Episode 410: Validation average reward = 399.32, vs Random = 390.03, vs Pretrained = 408.61
# Episode 411/500, Total Reward Blue: 407.90
# Episode 412/500, Total Reward Blue: 407.67
# Episode 413/500, Total Reward Blue: 408.89
# Episode 414/500, Total Reward Blue: 404.95
# Episode 415/500, Total Reward Blue: 403.04
# Episode 415: Validation average reward = 327.39, vs Random = 281.82, vs Pretrained = 372.96
# Episode 416/500, Total Reward Blue: 404.83
# Episode 417/500, Total Reward Blue: 407.50
# Episode 418/500, Total Reward Blue: 407.88
# Episode 419/500, Total Reward Blue: 405.86
# Episode 420/500, Total Reward Blue: 411.10
# Episode 420: Validation average reward = 381.81, vs Random = 404.34, vs Pretrained = 359.29
# Episode 421/500, Total Reward Blue: 405.34
# Episode 422/500, Total Reward Blue: 402.85
# Episode 423/500, Total Reward Blue: 396.05
# Episode 424/500, Total Reward Blue: 405.26
# Episode 425/500, Total Reward Blue: 407.67
# Episode 425: Validation average reward = 402.41, vs Random = 405.73, vs Pretrained = 399.10
# Episode 426/500, Total Reward Blue: 406.77
# Episode 427/500, Total Reward Blue: 407.09
# Episode 428/500, Total Reward Blue: 396.79
# Episode 429/500, Total Reward Blue: 402.28
# Episode 430/500, Total Reward Blue: 393.64
# Episode 430: Validation average reward = 399.54, vs Random = 402.55, vs Pretrained = 396.53
# Episode 431/500, Total Reward Blue: 409.40
# Episode 432/500, Total Reward Blue: 404.07
# Episode 433/500, Total Reward Blue: 407.45
# Episode 434/500, Total Reward Blue: 410.29
# Episode 435/500, Total Reward Blue: 406.08
# Episode 435: Validation average reward = 393.38, vs Random = 388.50, vs Pretrained = 398.27
# Episode 436/500, Total Reward Blue: 408.59
# Episode 437/500, Total Reward Blue: 406.59
# Episode 438/500, Total Reward Blue: 408.89
# Episode 439/500, Total Reward Blue: 395.34
# Episode 440/500, Total Reward Blue: 401.33
# Episode 440: Validation average reward = 395.65, vs Random = 400.95, vs Pretrained = 390.36
# Episode 441/500, Total Reward Blue: 405.45
# Episode 442/500, Total Reward Blue: 403.17
# Episode 443/500, Total Reward Blue: 408.70
# Episode 444/500, Total Reward Blue: 405.76
# Episode 445/500, Total Reward Blue: 409.07
# Episode 445: Validation average reward = 405.63, vs Random = 405.29, vs Pretrained = 405.97
# Episode 446/500, Total Reward Blue: 413.72
# Episode 447/500, Total Reward Blue: 408.76
# Episode 448/500, Total Reward Blue: 409.50
# Episode 449/500, Total Reward Blue: 405.75
# Episode 450/500, Total Reward Blue: 407.09
# Episode 450: Validation average reward = 400.24, vs Random = 403.34, vs Pretrained = 397.14
# Episode 451/500, Total Reward Blue: 410.58
# Episode 452/500, Total Reward Blue: 352.21
# Episode 453/500, Total Reward Blue: 413.87
# Episode 454/500, Total Reward Blue: 407.17
# Episode 455/500, Total Reward Blue: 407.38
# Episode 455: Validation average reward = 405.68, vs Random = 408.02, vs Pretrained = 403.33
# Episode 456/500, Total Reward Blue: 412.31
# Episode 457/500, Total Reward Blue: 406.78
# Episode 458/500, Total Reward Blue: 406.27
# Episode 459/500, Total Reward Blue: 407.38
# Episode 460/500, Total Reward Blue: 397.79
# Episode 460: Validation average reward = 403.93, vs Random = 406.38, vs Pretrained = 401.48
# Episode 461/500, Total Reward Blue: 407.26
# Episode 462/500, Total Reward Blue: 411.49
# Episode 463/500, Total Reward Blue: 408.30
# Episode 464/500, Total Reward Blue: 407.79
# Episode 465/500, Total Reward Blue: 409.60
# Episode 465: Validation average reward = 401.90, vs Random = 406.42, vs Pretrained = 397.38
# Episode 466/500, Total Reward Blue: 404.85
# Episode 467/500, Total Reward Blue: 398.81
# Episode 468/500, Total Reward Blue: 373.01
# Episode 469/500, Total Reward Blue: 403.66
# Episode 470/500, Total Reward Blue: 406.47
# Episode 470: Validation average reward = 391.26, vs Random = 372.78, vs Pretrained = 409.73
# Episode 471/500, Total Reward Blue: 405.77
# Episode 472/500, Total Reward Blue: 406.66
# Episode 473/500, Total Reward Blue: 408.89
# Episode 474/500, Total Reward Blue: 404.67
# Episode 475/500, Total Reward Blue: 405.16
# Episode 475: Validation average reward = 402.36, vs Random = 405.14, vs Pretrained = 399.58
# Episode 476/500, Total Reward Blue: 405.06
# Episode 477/500, Total Reward Blue: 403.35
# Episode 478/500, Total Reward Blue: 406.10
# Episode 479/500, Total Reward Blue: 408.81
# Episode 480/500, Total Reward Blue: 336.50
# Episode 480: Validation average reward = 387.16, vs Random = 376.12, vs Pretrained = 398.20
# Episode 481/500, Total Reward Blue: 406.93
# Episode 482/500, Total Reward Blue: 408.60
# Episode 483/500, Total Reward Blue: 391.75
# Episode 484/500, Total Reward Blue: 406.78
# Episode 485/500, Total Reward Blue: 403.53
# Episode 485: Validation average reward = 405.92, vs Random = 406.71, vs Pretrained = 405.13
# Episode 486/500, Total Reward Blue: 411.18
# Episode 487/500, Total Reward Blue: 408.79
# Episode 488/500, Total Reward Blue: 407.40
# Episode 489/500, Total Reward Blue: 405.67
# Episode 490/500, Total Reward Blue: 403.74
# Episode 490: Validation average reward = 405.15, vs Random = 406.16, vs Pretrained = 404.14
# Episode 491/500, Total Reward Blue: 405.38
# Episode 492/500, Total Reward Blue: 411.30
# Episode 493/500, Total Reward Blue: 409.46
# Episode 494/500, Total Reward Blue: 409.41
# Episode 495/500, Total Reward Blue: 405.97
# Episode 495: Validation average reward = 401.36, vs Random = 397.85, vs Pretrained = 404.88
# Episode 496/500, Total Reward Blue: 409.01
# Episode 497/500, Total Reward Blue: 408.90
# Episode 498/500, Total Reward Blue: 407.32
# Episode 499/500, Total Reward Blue: 410.91
# Episode 500/500, Total Reward Blue: 406.07
# Episode 500: Validation average reward = 406.32, vs Random = 404.75, vs Pretrained = 407.90
# Training complete. Best model saved at blue_agent_noisy_dueling_vdn_hypermixer_best.pth

# %%
import matplotlib.pyplot as plt
from tensorboard.backend.event_processing.event_accumulator import EventAccumulator
import os

# --- Function to extract data from TensorBoard logs ---
def extract_data_from_logs(log_dir, tags):
    event_acc = EventAccumulator(log_dir)
    event_acc.Reload()
    data = {tag: [] for tag in tags}

    for tag in tags:
        events = event_acc.Scalars(tag)
        for event in events:
            data[tag].append((event.step, event.value))

    return data

# --- Set log directory ---
log_dir = "/kaggle/working/runs"
latest_run = max([os.path.join(log_dir, d) for d in os.listdir(log_dir)], key=os.path.getmtime)

# --- Tags to plot ---
tags_to_plot = ['Total Reward/Blue','Validation/Average Reward','Validation/Average Reward vs Random','Validation/Average Reward vs Pretrained']
data = extract_data_from_logs(latest_run, tags_to_plot)

# --- Plot data ---
plt.figure(figsize=(15, 10))
for tag in tags_to_plot:
    steps, values = zip(*data[tag])
    plt.plot(steps, values, label=tag)

plt.xlabel("Steps")
plt.ylabel("Value")
plt.title("Training Metrics")
plt.legend()
plt.grid(True)
plt.show()
